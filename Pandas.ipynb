# %%
import pandas as pd

# %%
df = pd.read_csv("heart-disease.csv")

# %%
list1=[{"name":"Danish", "age": 21},
       {"name":"Ali", "age":22}]
df1= pd.DataFrame(list1)
df1
# Out:
#      name  age
# 0  Danish   21
# 1     Ali   22

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
i=df.iat[1,0]
i
# Out:
# np.int64(37)

# %%
df.iloc[1:5,3:]
# Out:
#    trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  \
# 1       130   250    0        1      187      0      3.5      0   0     2
# 2       130   204    0        0      172      0      1.4      2   0     2
# 3       120   236    0        1      178      0      0.8      2   0     2
# 4       120   354    0        1      163      1      0.6      2   0     2
#
#    target
# 1       1
# 2       1
# 3       1
# 4       1

# %%
dc= pd.read_csv("car-sales.csv")
dc
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
dc.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
dc1=dc[(dc['Price'] > '$5000') & (dc['Colour'] == 'Blue')]

# %%
data = dc['Colour']
s = pd.Series(data,name="Danish car colour")
s
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Danish car colour, dtype: str

# %%
dc1.to_csv("exported.csv") #Exported data in file

# %%
dc.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
dc.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
dc['Odometer (KM)'].mean()
# Out:
# np.float64(78601.4)

# %%
dc.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
dc.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 722.0 bytes

# %%
dc.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
len(df)
# Out:
# 303

# %%
dc
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # viewing and selecting data

# %%
dc.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
dc.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
dc.loc[3]  # loc refers to index
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
dc.iloc[3:,2:]  # ilco refers to position
# Out:
#    Odometer (KM)  Doors       Price
# 3          11179      5  $22,000.00
# 4         213095      4   $3,500.00
# 5          99213      4   $4,500.00
# 6          45698      4   $7,500.00
# 7          54738      4   $7,000.00
# 8          60000      4   $6,250.00
# 9          31600      4   $9,700.00

# %%
dc.at[3, "Price"]
# Out:
# '$22,000.00'

# %%
dc.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: str

# %%
pd.crosstab(dc['Make'],dc['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
dc.groupby(['Make','Colour'])['Odometer (KM)'].sum()
# Out:
# Make    Colour
# BMW     Black      11179
# Honda   Blue      100436
#         Red        87899
# Nissan  White     244695
# Toyota  Blue       32549
#         Green      99213
#         White     210043
# Name: Odometer (KM), dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dc['Doors'].hist()
# Out:
# <Axes: >

# %%
plt.hist(dc['Odometer (KM)'])
# Out:
# (array([1., 3., 2., 1., 1., 0., 1., 0., 0., 1.]),
#  array([ 11179. ,  31370.6,  51562.2,  71753.8,  91945.4, 112137. ,
#         132328.6, 152520.2, 172711.8, 192903.4, 213095. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(dc['Make'],np.sort(dc['Price']))
# Out:
# <BarContainer object of 10 artists>

# %%
dc['Price'] = (
    dc['Price']
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .astype(float)
    .astype(int)
)

# %%
plt.bar(dc['Make'],dc['Price'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.plot(dc['Price'])
plt.title("Price of Car in 2021")
plt.xlabel("Car Number")
plt.ylabel("Price of car")
plt.grid()
plt.show()

# %% [markdown]
# # Manipulating Data with Pandas

# %%
dc['Make'].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: str

# %% [markdown]
# # ADD and Drop  columns and rows

# %%
ser=pd.Series(np.arange(1,100,10))
dc['points']=ser

# %%
dc['Number of wheels']=4

# %%
dc
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  points  Number of wheels
# 0  Toyota  White         150043      4   4000       1                 4
# 1   Honda    Red          87899      4   5000      11                 4
# 2  Toyota   Blue          32549      3   7000      21                 4
# 3     BMW  Black          11179      5  22000      31                 4
# 4  Nissan  White         213095      4   3500      41                 4
# 5  Toyota  Green          99213      4   4500      51                 4
# 6   Honda   Blue          45698      4   7500      61                 4
# 7   Honda   Blue          54738      4   7000      71                 4
# 8  Toyota  White          60000      4   6250      81                 4
# 9  Nissan  White          31600      4   9700      91                 4

# %%
dc
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Number of wheels
# 0  Toyota  White         150043      4   4000                 4
# 1   Honda    Red          87899      4   5000                 4
# 2  Toyota   Blue          32549      3   7000                 4
# 3     BMW  Black          11179      5  22000                 4
# 4  Nissan  White         213095      4   3500                 4
# 5  Toyota  Green          99213      4   4500                 4
# 6   Honda   Blue          45698      4   7500                 4
# 7   Honda   Blue          54738      4   7000                 4
# 8  Toyota  White          60000      4   6250                 4
# 9  Nissan  White          31600      4   9700                 4

# %%
dc.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Number of wheels
# 0  Toyota  White         150043      4   4000                 4
# 4  Nissan  White         213095      4   3500                 4
# 8  Toyota  White          60000      4   6250                 4
# 6   Honda   Blue          45698      4   7500                 4
# 3     BMW  Black          11179      5  22000                 4
# 2  Toyota   Blue          32549      3   7000                 4
# 9  Nissan  White          31600      4   9700                 4
# 1   Honda    Red          87899      4   5000                 4
# 7   Honda   Blue          54738      4   7000                 4
# 5  Toyota  Green          99213      4   4500                 4

# %%
dc['Odometer (KM)']= dc['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
dc
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Number of wheels
# 0  Toyota  White      93776.875      4   4000                 4
# 1   Honda    Red      54936.875      4   5000                 4
# 2  Toyota   Blue      20343.125      3   7000                 4
# 3     BMW  Black       6986.875      5  22000                 4
# 4  Nissan  White     133184.375      4   3500                 4
# 5  Toyota  Green      62008.125      4   4500                 4
# 6   Honda   Blue      28561.250      4   7500                 4
# 7   Honda   Blue      34211.250      4   7000                 4
# 8  Toyota  White      37500.000      4   6250                 4
# 9  Nissan  White      19750.000      4   9700                 4
